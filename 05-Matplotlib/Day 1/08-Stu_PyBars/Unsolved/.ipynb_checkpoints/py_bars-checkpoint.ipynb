# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities)
fig,ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# Create the ticks for our bar chart's x axis

plt.xticks(x_axis, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x29af9711828>,
#   <matplotlib.axis.XTick at 0x29af9711160>,
#   <matplotlib.axis.XTick at 0x29af9733780>,
#   <matplotlib.axis.XTick at 0x29af9b31c50>,
#   <matplotlib.axis.XTick at 0x29af97687f0>],
#  <a list of 5 Text xticklabel objects>)

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis) - 0.25

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities))
ax.set_yticks(np.arange(1,10,0.5))
# Out:
# [<matplotlib.axis.YTick at 0x29afa04c748>,
#  <matplotlib.axis.YTick at 0x29afa04c080>,
#  <matplotlib.axis.YTick at 0x29af9751b70>,
#  <matplotlib.axis.YTick at 0x29afa07f630>,
#  <matplotlib.axis.YTick at 0x29afa069978>,
#  <matplotlib.axis.YTick at 0x29afa0990b8>,
#  <matplotlib.axis.YTick at 0x29af97487b8>,
#  <matplotlib.axis.YTick at 0x29afa072828>,
#  <matplotlib.axis.YTick at 0x29afa0a0a58>,
#  <matplotlib.axis.YTick at 0x29af9768fd0>,
#  <matplotlib.axis.YTick at 0x29afa03ca20>,
#  <matplotlib.axis.YTick at 0x29afa0995c0>,
#  <matplotlib.axis.YTick at 0x29afa099d30>,
#  <matplotlib.axis.YTick at 0x29afa099da0>,
#  <matplotlib.axis.YTick at 0x29afa847c50>,
#  <matplotlib.axis.YTick at 0x29af9ff8860>,
#  <matplotlib.axis.YTick at 0x29afa8472e8>,
#  <matplotlib.axis.YTick at 0x29afa0ad0f0>]

# %%
# Give the chart a title, x label, and y label
plt.axis()

# %%
# Save an image of the chart and print it to the screen
