# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    #print(lat_lng)
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 554

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url = "http://api.openweathermap.org/data/2.5/weather"
#query_dict = \
#{
#    'appid': api_key,
#}

cities_array = ['London','Tokyo','foobar','Austin']
output = []

for i in range(len(cities)):
    response = requests.get \
    (
        "http://api.openweathermap.org/data/2.5/weather",
        params= \
        {
            'appid': api_key,
            'q': cities[i],
            'units': 'metric'
        }
    )
    
    if response.json()['cod'] == 200:
        output.append(response.json())
        print(f'{i+1} | {cities[i]} | Weather data recorded')
    else:
        print(f'{i+1} | {cities[i]} | City not found, skipping...')
        
print(f'========== Finished Retreiving Data ==========')
# Out:
# 1 | devils lake | Weather data recorded
# 2 | pizarro | Weather data recorded
# 3 | albany | Weather data recorded
# 4 | jamestown | Weather data recorded
# 5 | kapaa | Weather data recorded
# 6 | kropotkin | Weather data recorded
# 7 | leningradskiy | Weather data recorded
# 8 | ostrovnoy | Weather data recorded
# 9 | folkestone | Weather data recorded
# 10 | nikolskoye | Weather data recorded
# 11 | hobart | Weather data recorded
# 12 | copiapo | Weather data recorded
# 13 | ribeira grande | Weather data recorded
# 14 | namatanai | Weather data recorded
# 15 | christchurch | Weather data recorded
# 16 | rikitea | Weather data recorded
# 17 | isla mujeres | Weather data recorded
# 18 | terme | Weather data recorded
# 19 | san cristobal | Weather data recorded
# 20 | sentyabrskiy | City not found, skipping...
# 21 | tuktoyaktuk | Weather data recorded
# 22 | busselton | Weather data recorded
# 23 | severo-kurilsk | Weather data recorded
# 24 | vaini | Weather data recorded
# 25 | upernavik | Weather data recorded
# 26 | komsomolskiy | Weather data recorded
# 27 | klaksvik | Weather data recorded
# 28 | karratha | Weather data recorded
# 29 | belmonte | Weather data recorded
# 30 | mar del plata | Weather data recorded
# 31 | castro | Weather data recorded
# 32 | port blair | Weather data recorded
# 33 | tambura | City not found, skipping...
# 34 | fortuna | Weather data recorded
# 35 | nanortalik | Weather data recorded
# 36 | kodiak | Weather data recorded
# 37 | puerto ayora | Weather data recorded
# 38 | barentsburg | City not found, skipping...
# 39 | avarua | Weather data recorded
# 40 | makakilo city | Weather data recorded
# 41 | new norfolk | Weather data recorded
# 42 | bathsheba | Weather data recorded
# 43 | tiksi | Weather data recorded
# 44 | punta arenas | Weather data recorded
# 45 | mega | Weather data recorded
# 46 | butaritari | Weather data recorded
# 47 | clyde river | Weather data recorded
# 48 | barrow | Weather data recorded
# 49 | hithadhoo | Weather data recorded
# 50 | bluff | Weather data recorded
# 51 | north las vegas | Weather data recorded
# 52 | murud | City not found, skipping...
# 53 | nome | Weather data recorded
# 54 | cherskiy | Weather data recorded
# 55 | rawah | City not found, skipping...
# 56 | puerto escondido | Weather data recorded
# 57 | ushuaia | Weather data recorded
# 58 | asau | City not found, skipping...
# 59 | mackay | Weather data recorded
# 60 | saskylakh | Weather data recorded
# 61 | marabba | Weather data recorded
# 62 | netivot | Weather data recorded
# 63 | valleyview | Weather data recorded
# 64 | kavieng | Weather data recorded
# 65 | new ulm | Weather data recorded
# 66 | atuona | Weather data recorded
# 67 | coahuayana | Weather data recorded
# 68 | ilulissat | Weather data recorded
# 69 | palabuhanratu | City not found, skipping...
# 70 | goundi | Weather data recorded
# 71 | esperance | Weather data recorded
# 72 | guanica | Weather data recorded
# 73 | illoqqortoormiut | City not found, skipping...
# 74 | lexington | Weather data recorded
# 75 | atikokan | Weather data recorded
# 76 | kyaikkami | Weather data recorded
# 77 | meulaboh | Weather data recorded
# 78 | thompson | Weather data recorded
# 79 | mount isa | Weather data recorded
# 80 | lufilufi | Weather data recorded
# 81 | newport | Weather data recorded
# 82 | cazaje | City not found, skipping...
# 83 | nyurba | Weather data recorded
# 84 | lagoa | Weather data recorded
# 85 | belaya gora | Weather data recorded
# 86 | victoria | Weather data recorded
# 87 | shaunavon | Weather data recorded
# 88 | cape town | Weather data recorded
# 89 | taolanaro | City not found, skipping...
# 90 | okha | Weather data recorded
# 91 | san patricio | Weather data recorded
# 92 | bethel | Weather data recorded
# 93 | atkinson | Weather data recorded
# 94 | ahipara | Weather data recorded
# 95 | inuvik | Weather data recorded
# 96 | georgetown | Weather data recorded
# 97 | buchanan | Weather data recorded
# 98 | saint-philippe | Weather data recorded
# 99 | rungata | City not found, skipping...
# 100 | rio grande | Weather data recorded
# 101 | porto novo | Weather data recorded
# 102 | inongo | Weather data recorded
# 103 | salalah | Weather data recorded
# 104 | chokurdakh | Weather data recorded
# 105 | san policarpo | Weather data recorded
# 106 | bredasdorp | Weather data recorded
# 107 | mataura | Weather data recorded
# 108 | tanout | Weather data recorded
# 109 | dikson | Weather data recorded
# 110 | carnarvon | Weather data recorded
# 111 | ler | Weather data recorded
# 112 | lebu | Weather data recorded
# 113 | catamarca | City not found, skipping...
# 114 | mahebourg | Weather data recorded
# 115 | dingle | Weather data recorded
# 116 | prado | Weather data recorded
# 117 | emerald | Weather data recorded
# 118 | te anau | Weather data recorded
# 119 | pangai | Weather data recorded
# 120 | rorvik | Weather data recorded
# 121 | tabiauea | City not found, skipping...
# 122 | east london | Weather data recorded
# 123 | faya | Weather data recorded
# 124 | belushya guba | City not found, skipping...
# 125 | biak | Weather data recorded
# 126 | saldanha | Weather data recorded
# 127 | jumla | Weather data recorded
# 128 | davis | Weather data recorded
# 129 | sitka | Weather data recorded
# 130 | kysyl-syr | Weather data recorded
# 131 | ishigaki | Weather data recorded
# 132 | rawson | Weather data recorded
# 133 | nerchinsk | Weather data recorded
# 134 | attawapiskat | City not found, skipping...
# 135 | arraial do cabo | Weather data recorded
# 136 | morondava | Weather data recorded
# 137 | hermanus | Weather data recorded
# 138 | oconomowoc | Weather data recorded
# 139 | iqaluit | Weather data recorded
# 140 | honningsvag | Weather data recorded
# 141 | roma | Weather data recorded
# 142 | qostanay | Weather data recorded
# 143 | margate | Weather data recorded
# 144 | kuche | City not found, skipping...
# 145 | vila do maio | Weather data recorded
# 146 | bambous virieux | Weather data recorded
# 147 | berezovyy | Weather data recorded
# 148 | poum | Weather data recorded
# 149 | muravlenko | Weather data recorded
# 150 | yellowknife | Weather data recorded
# 151 | balkhash | Weather data recorded
# 152 | broome | Weather data recorded
# 153 | byron bay | Weather data recorded
# 154 | anadyr | Weather data recorded
# 155 | hamilton | Weather data recorded
# 156 | hovd | Weather data recorded
# 157 | phan rang | City not found, skipping...
# 158 | caravelas | Weather data recorded
# 159 | key west | Weather data recorded
# 160 | sola | Weather data recorded
# 161 | hilo | Weather data recorded
# 162 | bandar-e lengeh | Weather data recorded
# 163 | tamale | Weather data recorded
# 164 | jardim | Weather data recorded
# 165 | ulladulla | Weather data recorded
# 166 | ginda | Weather data recorded
# 167 | hiranagar | Weather data recorded
# 168 | matara | Weather data recorded
# 169 | khatanga | Weather data recorded
# 170 | altay | Weather data recorded
# 171 | quatre cocos | Weather data recorded
# 172 | cidreira | Weather data recorded
# 173 | lazaro cardenas | Weather data recorded
# 174 | katsuura | Weather data recorded
# 175 | leshukonskoye | Weather data recorded
# 176 | oxbow | Weather data recorded
# 177 | shaoyang | Weather data recorded
# 178 | manzil salim | Weather data recorded
# 179 | port hope | Weather data recorded
# 180 | bengkulu | City not found, skipping...
# 181 | huaral | Weather data recorded
# 182 | lompoc | Weather data recorded
# 183 | flinders | Weather data recorded
# 184 | touros | Weather data recorded
# 185 | guerrero negro | Weather data recorded
# 186 | sechura | Weather data recorded
# 187 | sao filipe | Weather data recorded
# 188 | syracuse | Weather data recorded
# 189 | paka | Weather data recorded
# 190 | sakakah | City not found, skipping...
# 191 | tasiilaq | Weather data recorded
# 192 | airai | Weather data recorded
# 193 | kruisfontein | Weather data recorded
# 194 | benghazi | Weather data recorded
# 195 | naze | Weather data recorded
# 196 | talara | Weather data recorded
# 197 | north bend | Weather data recorded
# 198 | chuy | Weather data recorded
# 199 | hami | Weather data recorded
# 200 | samarai | Weather data recorded
# 201 | karkaralinsk | City not found, skipping...
# 202 | baykit | Weather data recorded
# 203 | yuanping | Weather data recorded
# 204 | bolungarvik | City not found, skipping...
# 205 | tymovskoye | Weather data recorded
# 206 | sharjah | Weather data recorded
# 207 | mys shmidta | City not found, skipping...
# 208 | pacifica | Weather data recorded
# 209 | lushunkou | City not found, skipping...
# 210 | chumikan | Weather data recorded
# 211 | ponta do sol | Weather data recorded
# 212 | beloha | Weather data recorded
# 213 | auki | Weather data recorded
# 214 | knyaze-volkonskoye | Weather data recorded
# 215 | comodoro rivadavia | Weather data recorded
# 216 | burgeo | Weather data recorded
# 217 | port alfred | Weather data recorded
# 218 | hasaki | Weather data recorded
# 219 | lasa | Weather data recorded
# 220 | miranda | Weather data recorded
# 221 | lizzano | Weather data recorded
# 222 | san rafael | Weather data recorded
# 223 | kidal | Weather data recorded
# 224 | bonavista | Weather data recorded
# 225 | vaitupu | City not found, skipping...
# 226 | pangnirtung | Weather data recorded
# 227 | mawlaik | Weather data recorded
# 228 | nuuk | Weather data recorded
# 229 | preobrazheniye | Weather data recorded
# 230 | ixtapa | Weather data recorded
# 231 | parati | Weather data recorded
# 232 | havelock | Weather data recorded
# 233 | provideniya | Weather data recorded
# 234 | tiznit | Weather data recorded
# 235 | shingu | Weather data recorded
# 236 | kailasahar | City not found, skipping...
# 237 | paradwip | City not found, skipping...
# 238 | lorengau | Weather data recorded
# 239 | kieta | Weather data recorded
# 240 | ucluelet | Weather data recorded
# 241 | longyearbyen | Weather data recorded
# 242 | narsaq | Weather data recorded
# 243 | ampanihy | Weather data recorded
# 244 | bubaque | Weather data recorded
# 245 | shiyan | Weather data recorded
# 246 | maceio | Weather data recorded
# 247 | kavaratti | Weather data recorded
# 248 | grakhovo | Weather data recorded
# 249 | san quintin | Weather data recorded
# 250 | makinsk | Weather data recorded
# 251 | tsihombe | City not found, skipping...
# 252 | caconda | Weather data recorded
# 253 | batticaloa | Weather data recorded
# 254 | aquiraz | Weather data recorded
# 255 | sao joao da barra | Weather data recorded
# 256 | tessalit | Weather data recorded
# 257 | ketchikan | Weather data recorded
# 258 | tevaitoa | Weather data recorded
# 259 | pochutla | Weather data recorded
# 260 | kismayo | City not found, skipping...
# 261 | muros | Weather data recorded
# 262 | bull savanna | Weather data recorded
# 263 | qaanaaq | Weather data recorded
# 264 | vardo | Weather data recorded
# 265 | tarakan | Weather data recorded
# 266 | sabzevar | Weather data recorded
# 267 | neiafu | Weather data recorded
# 268 | samusu | City not found, skipping...
# 269 | itarema | Weather data recorded
# 270 | grand river south east | City not found, skipping...
# 271 | longyan | Weather data recorded
# 272 | ye | City not found, skipping...
# 273 | vila franca do campo | Weather data recorded
# 274 | ancud | Weather data recorded
# 275 | khiri mat | Weather data recorded
# 276 | richards bay | Weather data recorded
# 277 | svetlogorsk | Weather data recorded
# 278 | nhulunbuy | Weather data recorded
# 279 | hihifo | City not found, skipping...
# 280 | kamenka | Weather data recorded
# 281 | qasigiannguit | Weather data recorded
# 282 | mackenzie | Weather data recorded
# 283 | tres lagoas | City not found, skipping...
# 284 | malumfashi | Weather data recorded
# 285 | shirokiy | Weather data recorded
# 286 | amderma | City not found, skipping...
# 287 | pietarsaari | City not found, skipping...
# 288 | gainesville | Weather data recorded
# 289 | luderitz | Weather data recorded
# 290 | shache | Weather data recorded
# 291 | biltine | Weather data recorded
# 292 | rassvet | Weather data recorded
# 293 | jimma | Weather data recorded
# 294 | kerouane | Weather data recorded
# 295 | souillac | Weather data recorded
# 296 | doctor pedro p. pena | City not found, skipping...
# 297 | hammerfest | Weather data recorded
# 298 | tumannyy | City not found, skipping...
# 299 | korla | City not found, skipping...
# 300 | kaeo | Weather data recorded
# 301 | hambantota | Weather data recorded
# 302 | port augusta | Weather data recorded
# 303 | saryshagan | City not found, skipping...
# 304 | berlevag | Weather data recorded
# 305 | marang | City not found, skipping...
# 306 | fairbanks | Weather data recorded
# 307 | halifax | Weather data recorded
# 308 | villaviciosa | Weather data recorded
# 309 | simao | Weather data recorded
# 310 | tuatapere | Weather data recorded
# 311 | batouri | Weather data recorded
# 312 | lypnyazhka | Weather data recorded
# 313 | sabang | Weather data recorded
# 314 | nanning | Weather data recorded
# 315 | xingtai | Weather data recorded
# 316 | kaputa | Weather data recorded
# 317 | maniwaki | Weather data recorded
# 318 | barra do garcas | Weather data recorded
# 319 | chowchilla | Weather data recorded
# 320 | san vicente | Weather data recorded
# 321 | laguna | Weather data recorded
# 322 | krasnoarmeyskoye | Weather data recorded
# 323 | yavaros | Weather data recorded
# 324 | daru | Weather data recorded
# 325 | alice springs | Weather data recorded
# 326 | ushtobe | Weather data recorded
# 327 | turukhansk | Weather data recorded
# 328 | isangel | Weather data recorded
# 329 | guhagar | Weather data recorded
# 330 | yulara | Weather data recorded
# 331 | mantua | Weather data recorded
# 332 | abu samrah | Weather data recorded
# 333 | palana | Weather data recorded
# 334 | porto santo | City not found, skipping...
# 335 | tokur | Weather data recorded
# 336 | doha | Weather data recorded
# 337 | krasnyy chikoy | Weather data recorded
# 338 | shenzhen | Weather data recorded
# 339 | kaseda | Weather data recorded
# 340 | gasa | Weather data recorded
# 341 | muroto | Weather data recorded
# 342 | dudinka | Weather data recorded
# 343 | nelson bay | Weather data recorded
# 344 | kinanah | City not found, skipping...
# 345 | gat | Weather data recorded
# 346 | portland | Weather data recorded
# 347 | yar-sale | Weather data recorded
# 348 | marzuq | Weather data recorded
# 349 | alofi | Weather data recorded
# 350 | vila velha | Weather data recorded
# 351 | oskaloosa | Weather data recorded
# 352 | carahue | Weather data recorded
# 353 | nizhneyansk | City not found, skipping...
# 354 | charters towers | Weather data recorded
# 355 | kearney | Weather data recorded
# 356 | bandarbeyla | Weather data recorded
# 357 | carnot | Weather data recorded
# 358 | baghdad | Weather data recorded
# 359 | fallon | Weather data recorded
# 360 | warqla | City not found, skipping...
# 361 | kenai | Weather data recorded
# 362 | port hardy | Weather data recorded
# 363 | champerico | Weather data recorded
# 364 | marcona | City not found, skipping...
# 365 | cravo norte | Weather data recorded
# 366 | lolua | City not found, skipping...
# 367 | kirensk | Weather data recorded
# 368 | sigmaringen | Weather data recorded
# 369 | zhigansk | Weather data recorded
# 370 | kragero | Weather data recorded
# 371 | utica | Weather data recorded
# 372 | casino | Weather data recorded
# 373 | killybegs | Weather data recorded
# 374 | sokoni | Weather data recorded
# 375 | rantepao | Weather data recorded
# 376 | pozo de gamboa | City not found, skipping...
# 377 | wilmington | Weather data recorded
# 378 | port elizabeth | Weather data recorded
# 379 | cabedelo | Weather data recorded
# 380 | beringovskiy | Weather data recorded
# 381 | ambulu | Weather data recorded
# 382 | urdzhar | City not found, skipping...
# 383 | nsanje | Weather data recorded
# 384 | khandyga | Weather data recorded
# 385 | tual | Weather data recorded
# 386 | steinbach | Weather data recorded
# 387 | norman wells | Weather data recorded
# 388 | padang | Weather data recorded
# 389 | avera | Weather data recorded
# 390 | barbar | City not found, skipping...
# 391 | haines junction | Weather data recorded
# 392 | sompeta | Weather data recorded
# 393 | saint-georges | Weather data recorded
# 394 | asfi | City not found, skipping...
# 395 | torbay | Weather data recorded
# 396 | candido mendes | Weather data recorded
# 397 | erenhot | Weather data recorded
# 398 | tahoua | Weather data recorded
# 399 | kailua | Weather data recorded
# 400 | aitape | Weather data recorded
# 401 | winslow | Weather data recorded
# 402 | megion | Weather data recorded
# 403 | alotau | City not found, skipping...
# 404 | hanyang | Weather data recorded
# 405 | concordia | Weather data recorded
# 406 | knysna | Weather data recorded
# 407 | iracoubo | Weather data recorded
# 408 | zagare | Weather data recorded
# 409 | liverpool | Weather data recorded
# 410 | bandar-e torkaman | City not found, skipping...
# 411 | angelholm | City not found, skipping...
# 412 | troitsko-pechorsk | Weather data recorded
# 413 | college | Weather data recorded
# 414 | shonguy | Weather data recorded
# 415 | nouadhibou | Weather data recorded
# 416 | pirgos | Weather data recorded
# 417 | slavkov u brna | Weather data recorded
# 418 | sumbawa | City not found, skipping...
# 419 | tocopilla | Weather data recorded
# 420 | bend | Weather data recorded
# 421 | villa rica | Weather data recorded
# 422 | elko | Weather data recorded
# 423 | domoni | City not found, skipping...
# 424 | yarensk | Weather data recorded
# 425 | iquitos | Weather data recorded
# 426 | filadelfia | Weather data recorded
# 427 | astoria | Weather data recorded
# 428 | maneadero | City not found, skipping...
# 429 | celina | Weather data recorded
# 430 | kimbe | Weather data recorded
# 431 | gopalganj | Weather data recorded
# 432 | cabo san lucas | Weather data recorded
# 433 | ust-tsilma | Weather data recorded
# 434 | bayir | Weather data recorded
# 435 | socorro | Weather data recorded
# 436 | yenagoa | Weather data recorded
# 437 | kabare | Weather data recorded
# 438 | salinopolis | Weather data recorded
# 439 | port hedland | Weather data recorded
# 440 | kaitangata | Weather data recorded
# 441 | pelym | Weather data recorded
# 442 | geraldton | Weather data recorded
# 443 | imbituba | Weather data recorded
# 444 | big spring | Weather data recorded
# 445 | waw | City not found, skipping...
# 446 | palmer | Weather data recorded
# 447 | sioux lookout | Weather data recorded
# 448 | nishihara | Weather data recorded
# 449 | tabuk | Weather data recorded
# 450 | peniche | Weather data recorded
# 451 | kashan | Weather data recorded
# 452 | vestmannaeyjar | Weather data recorded
# 453 | shimoda | Weather data recorded
# 454 | perbaungan | City not found, skipping...
# 455 | rostovka | Weather data recorded
# 456 | tasbuget | City not found, skipping...
# 457 | beyneu | Weather data recorded
# 458 | buraydah | Weather data recorded
# 459 | praia | Weather data recorded
# 460 | merauke | Weather data recorded
# 461 | okato | Weather data recorded
# 462 | araouane | Weather data recorded
# 463 | sosua | Weather data recorded
# 464 | yenotayevka | Weather data recorded
# 465 | constantine | Weather data recorded
# 466 | takoradi | Weather data recorded
# 467 | sumisip | Weather data recorded
# 468 | olinda | Weather data recorded
# 469 | puerto penasco | Weather data recorded
# 470 | tautira | Weather data recorded
# 471 | dongli | Weather data recorded
# 472 | canto do buriti | Weather data recorded
# 473 | vestmanna | Weather data recorded
# 474 | qaqortoq | Weather data recorded
# 475 | deputatskiy | Weather data recorded
# 476 | rosarito | Weather data recorded
# 477 | boyabat | Weather data recorded
# 478 | muncar | Weather data recorded
# 479 | darhan | Weather data recorded
# 480 | strezhevoy | Weather data recorded
# 481 | menomonie | Weather data recorded
# 482 | poso | Weather data recorded
# 483 | visby | Weather data recorded
# 484 | pevek | Weather data recorded
# 485 | turayf | Weather data recorded
# 486 | rocha | Weather data recorded
# 487 | ossora | Weather data recorded
# 488 | palu | Weather data recorded
# 489 | felanitx | Weather data recorded
# 490 | ratnagiri | Weather data recorded
# 491 | portel | Weather data recorded
# 492 | dubbo | Weather data recorded
# 493 | malaya vishera | Weather data recorded
# 494 | saleaula | City not found, skipping...
# 495 | khasan | Weather data recorded
# 496 | ornskoldsvik | Weather data recorded
# 497 | darnah | Weather data recorded
# 498 | zenzeli | Weather data recorded
# 499 | farah | Weather data recorded
# 500 | san andres | Weather data recorded
# 501 | tolaga bay | Weather data recorded
# 502 | taltal | Weather data recorded
# 503 | guangyuan | Weather data recorded
# 504 | arcelia | Weather data recorded
# 505 | bacalar | Weather data recorded
# 506 | san ramon | Weather data recorded
# 507 | aloleng | Weather data recorded
# 508 | tanshui | City not found, skipping...
# 509 | rab | City not found, skipping...
# 510 | cervo | Weather data recorded
# 511 | sorland | Weather data recorded
# 512 | lucapa | Weather data recorded
# 513 | ugoofaaru | Weather data recorded
# 514 | ambon | Weather data recorded
# 515 | phonhong | Weather data recorded
# 516 | montepuez | Weather data recorded
# 517 | santo angelo | Weather data recorded
# 518 | lata | Weather data recorded
# 519 | chicama | Weather data recorded
# 520 | hervey bay | Weather data recorded
# 521 | fuerte olimpo | Weather data recorded
# 522 | jiazi | Weather data recorded
# 523 | acari | Weather data recorded
# 524 | parkersburg | Weather data recorded
# 525 | san carlos de bariloche | Weather data recorded
# 526 | bulgan | Weather data recorded
# 527 | henties bay | Weather data recorded
# 528 | kushalgarh | Weather data recorded
# 529 | ilorin | Weather data recorded
# 530 | la rioja | Weather data recorded
# 531 | praia da vitoria | Weather data recorded
# 532 | cherepovets | Weather data recorded
# 533 | omsk | Weather data recorded
# 534 | murgab | Weather data recorded
# 535 | puerto del rosario | Weather data recorded
# 536 | saint george | Weather data recorded
# 537 | kamaishi | Weather data recorded
# 538 | maumere | Weather data recorded
# 539 | crab hill | City not found, skipping...
# 540 | buala | Weather data recorded
# 541 | mitsamiouli | Weather data recorded
# 542 | mazatlan | Weather data recorded
# 543 | eureka | Weather data recorded
# 544 | maldonado | Weather data recorded
# 545 | aklavik | Weather data recorded
# 546 | sisimiut | Weather data recorded
# 547 | srednekolymsk | Weather data recorded
# 548 | lodwar | Weather data recorded
# 549 | dimapur | Weather data recorded
# 550 | paita | Weather data recorded
# 551 | aguascalientes | Weather data recorded
# 552 | itajuba | Weather data recorded
# 553 | gamba | Weather data recorded
# 554 | alcantarilla | Weather data recorded
# ========== Finished Retreiving Data ==========

# %%
len(output)
# Out:
# 491

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df_list = []

for i in range(len(output)):
    df_list.append \
    ([
        output[i]['name'],   # City name
        output[i]['sys']['country'],   # Country
        time.strftime("%d %b %Y %H:%M:%S" ,time.gmtime(output[i]['dt'])),   # Date
        output[i]['coord']['lat'],   # Latitude
        output[i]['coord']['lon'],   # Longitude
        output[i]['main']['temp_max'],   # Max temperature
        output[i]['main']['humidity'],   # Humidity
        output[i]['clouds']['all'],   # Cloudiness
        output[i]['wind']['speed']   # Wind speed
    ])

result_df = pd.DataFrame \
(
    df_list, 
    columns= \
    [
        'Name',
        'Country',
        'Date',
        'Latitude',
        'Longitude',
        'Max Temperature',
        'Humidity',
        'Cloudiness',
        'Wind Speed'
    ]
)

record_date = '10/13/2019'

result_df.to_csv(path_or_buf='output.csv',index=False)
result_df.head()
# Out:
#           Name Country                  Date  Latitude  Longitude  \
# 0  Devils Lake      US  16 Oct 2019 01:38:46     48.11     -98.87
# 1      Pizarro      CO  16 Oct 2019 01:38:46      4.95     -77.37
# 2       Albany      US  16 Oct 2019 01:38:47     42.65     -73.75
# 3    Jamestown      AU  16 Oct 2019 01:38:47    -33.21     138.60
# 4        Kapaa      US  16 Oct 2019 01:38:47     22.08    -159.32
#
#    Max Temperature  Humidity  Cloudiness  Wind Speed
# 0             2.00       100          90       3.600
# 1            25.45        83         100       1.229
# 2             8.33        70          20       1.864
# 3            16.55        57          97       4.517
# 4            28.00        74          75       7.200

# %%
output[1]
# Out:
# {'coord': {'lon': -53.46, 'lat': -33.69},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'model',
#  'main': {'temp': 12.27,
#   'pressure': 1022,
#   'humidity': 72,
#   'temp_min': 12.27,
#   'temp_max': 12.27,
#   'sea_level': 1022,
#   'grnd_level': 1021.62},
#  'wind': {'speed': 6.355, 'deg': 172},
#  'clouds': {'all': 89},
#  'dt': 1571014027,
#  'sys': {'country': 'UY', 'sunrise': 1570956911, 'sunset': 1571003085},
#  'timezone': -10800,
#  'id': 3443061,
#  'name': 'Chuy',
#  'cod': 200}

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Max Temperature'])

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.title(f'Max Temperature vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Temp_v_Lat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Humidity vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Humidity_v_Lat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Cloudiness vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Clouds_v_Lat.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Wind Speed'])

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f'Wind Speed vs. Latitude of Cities\nRecorded on {record_date}')

plt.savefig('Wind_v_Lat.png')

plt.show()
