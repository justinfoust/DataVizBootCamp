# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    #print(lat_lng)
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url = "http://api.openweathermap.org/data/2.5/weather"
#query_dict = \
#{
#    'appid': api_key,
#}

cities_array = ['London','Tokyo','foobar','Austin']
output = []

for city in cities:
    response = requests.get \
    (
        "http://api.openweathermap.org/data/2.5/weather",
        params= \
        {
            'appid': api_key,
            'q': city,
            'units': 'metric'
        }
    )
    
    if response.json()['cod'] == 200:
        output.append(response.json())
        print(f'Weather data for {city} recorded')
    else:
        print(f'{city} not found, skipping...')
# Out:
# Weather data for port elizabeth recorded
# Weather data for vaini recorded
# Weather data for jolalpan recorded
# Weather data for dire dawa recorded
# Weather data for thompson recorded
# Weather data for bluff recorded
# Weather data for tuktoyaktuk recorded
# Weather data for aksarka recorded
# Weather data for castro recorded
# Weather data for rikitea recorded
# Weather data for jamestown recorded
# Weather data for singaparna recorded
# Weather data for shimoda recorded
# Weather data for tura recorded
# Weather data for bambous virieux recorded
# Weather data for miri recorded
# Weather data for punta arenas recorded
# Weather data for ugoofaaru recorded
# taolanaro not found, skipping...
# Weather data for chicama recorded
# Weather data for new norfolk recorded
# Weather data for qaanaaq recorded
# Weather data for hilo recorded
# Weather data for dikson recorded
# Weather data for milkovo recorded
# Weather data for albany recorded
# attawapiskat not found, skipping...
# Weather data for nanortalik recorded
# Weather data for hami recorded
# Weather data for acajutla recorded
# Weather data for gladstone recorded
# Weather data for gilgit recorded
# Weather data for east london recorded
# Weather data for mataura recorded
# Weather data for katangli recorded
# Weather data for yellowknife recorded
# Weather data for fairbanks recorded
# Weather data for turukhansk recorded
# andenes not found, skipping...
# Weather data for ushuaia recorded
# Weather data for plouzane recorded
# Weather data for avera recorded
# Weather data for belmonte recorded
# ye not found, skipping...
# Weather data for maniitsoq recorded
# Weather data for beloha recorded
# Weather data for yulara recorded
# Weather data for walvis bay recorded
# Weather data for lac-megantic recorded
# Weather data for aswan recorded
# Weather data for kaitangata recorded
# Weather data for gat recorded
# Weather data for hobart recorded
# Weather data for tauranga recorded
# Weather data for yicheng recorded
# Weather data for faanui recorded
# Weather data for sugar hill recorded
# belushya guba not found, skipping...
# Weather data for culiacan recorded
# Weather data for guymon recorded
# Weather data for tiksi recorded
# Weather data for los llanos de aridane recorded
# illoqqortoormiut not found, skipping...
# Weather data for iqaluit recorded
# Weather data for alofi recorded
# Weather data for saint-augustin recorded
# Weather data for hasaki recorded
# Weather data for ngunguru recorded
# Weather data for puerto ayora recorded
# Weather data for rogers recorded
# Weather data for port macquarie recorded
# Weather data for monrovia recorded
# Weather data for geraldton recorded
# Weather data for balsas recorded
# ondorhaan not found, skipping...
# Weather data for tamboril recorded
# Weather data for port hardy recorded
# Weather data for atuona recorded
# Weather data for ahipara recorded
# Weather data for busselton recorded
# Weather data for vuktyl recorded
# sayabec not found, skipping...
# Weather data for itoman recorded
# Weather data for hobyo recorded
# Weather data for ithaca recorded
# tarudant not found, skipping...
# Weather data for tabas recorded
# Weather data for butaritari recorded
# Weather data for coahuayana recorded
# Weather data for hithadhoo recorded
# Weather data for port alfred recorded
# Weather data for codrington recorded
# Weather data for port lincoln recorded
# Weather data for coruripe recorded
# karamea not found, skipping...
# Weather data for hermanus recorded
# amderma not found, skipping...
# Weather data for esperance recorded
# Weather data for mar del plata recorded
# one hundred mile house not found, skipping...
# palasa not found, skipping...
# Weather data for mount gambier recorded
# Weather data for saskylakh recorded
# Weather data for port hedland recorded
# Weather data for upernavik recorded
# Weather data for cape town recorded
# Weather data for te anau recorded
# asfi not found, skipping...
# Weather data for chase recorded
# Weather data for kiama recorded
# mys shmidta not found, skipping...
# Weather data for sherghati recorded
# Weather data for saint-joseph recorded
# Weather data for severo-kurilsk recorded
# Weather data for isangel recorded
# bengkulu not found, skipping...
# Weather data for sur recorded
# Weather data for waddan recorded
# Weather data for karratha recorded
# Weather data for barrow recorded
# Weather data for san quintin recorded
# Weather data for pontinia recorded
# Weather data for ust-nera recorded
# Weather data for moron recorded
# Weather data for praia recorded
# Weather data for port augusta recorded
# Weather data for kapaa recorded
# Weather data for tezu recorded
# Weather data for soe recorded
# Weather data for nome recorded
# Weather data for chuy recorded
# Weather data for pangnirtung recorded
# asau not found, skipping...
# palabuhanratu not found, skipping...
# Weather data for kuantan recorded
# Weather data for sarkand recorded
# Weather data for dingle recorded
# Weather data for khatanga recorded
# Weather data for arraial do cabo recorded
# Weather data for constitucion recorded
# Weather data for laguna recorded
# Weather data for san pedro recorded
# Weather data for collierville recorded
# Weather data for viedma recorded
# Weather data for alto piquiri recorded
# Weather data for saint-philippe recorded
# Weather data for assens recorded
# Weather data for bredasdorp recorded
# Weather data for tuatapere recorded
# Weather data for la trinidad recorded
# stornoway not found, skipping...
# Weather data for iguape recorded
# Weather data for makat recorded
# Weather data for inhambane recorded
# Weather data for zapolyarnyy recorded
# armacao dos buzios not found, skipping...
# Weather data for wasilla recorded
# Weather data for ekuvukeni recorded
# Weather data for san patricio recorded
# Weather data for cadillac recorded
# Weather data for fukue recorded
# Weather data for nauta recorded
# Weather data for ixtapa recorded
# Weather data for lasa recorded
# Weather data for bandarbeyla recorded
# Weather data for beira recorded
# Weather data for nikolskoye recorded
# Weather data for namatanai recorded
# Weather data for libohove recorded
# Weather data for atar recorded
# Weather data for mayo recorded
# Weather data for bolshaya rechka recorded
# Weather data for kachug recorded
# Weather data for victoria recorded
# Weather data for eureka recorded
# Weather data for komsomolskiy recorded
# Weather data for imperial recorded
# Weather data for cockburn town recorded
# Weather data for avarua recorded
# Weather data for antofagasta recorded
# Weather data for vallenar recorded
# Weather data for yinchuan recorded
# Weather data for moose factory recorded
# Weather data for tomatlan recorded
# Weather data for mahebourg recorded
# Weather data for mehamn recorded
# Weather data for provideniya recorded
# Weather data for lavrentiya recorded
# nguiu not found, skipping...
# Weather data for tigil recorded
# Weather data for sao joao da barra recorded
# Weather data for leningradskiy recorded
# Weather data for hidrolandia recorded
# Weather data for fort-shevchenko recorded
# Weather data for poum recorded
# Weather data for marsh harbour recorded
# Weather data for kavieng recorded
# Weather data for carnarvon recorded
# grand river south east not found, skipping...
# Weather data for malazgirt recorded
# Weather data for russell recorded
# Weather data for sembakung recorded
# Weather data for mnogovershinnyy recorded
# Weather data for las palmas recorded
# Weather data for omboue recorded
# Weather data for ribeira grande recorded
# Weather data for japura recorded
# Weather data for torbay recorded
# Weather data for ponta do sol recorded
# Weather data for meulaboh recorded
# Weather data for mpika recorded
# Weather data for buraydah recorded
# Weather data for killam recorded
# Weather data for luderitz recorded
# Weather data for cayenne recorded
# theologos not found, skipping...
# Weather data for naze recorded
# Weather data for tasiilaq recorded
# Weather data for verkhnyaya inta recorded
# Weather data for ilulissat recorded
# Weather data for vestmannaeyjar recorded
# Weather data for kodiak recorded
# Weather data for hofn recorded
# Weather data for cabo san lucas recorded
# Weather data for skelleftea recorded
# Weather data for puerto escondido recorded
# Weather data for kuopio recorded
# Weather data for iisalmi recorded
# Weather data for weligama recorded
# samusu not found, skipping...
# azimur not found, skipping...
# Weather data for honningsvag recorded
# Weather data for vardo recorded
# Weather data for talnakh recorded
# Weather data for kyren recorded
# Weather data for gewane recorded
# Weather data for comodoro rivadavia recorded
# Weather data for guerrero negro recorded
# Weather data for am timan recorded
# Weather data for samarai recorded
# Weather data for norman wells recorded
# Weather data for boyuibe recorded
# Weather data for yanggu recorded
# Weather data for lebu recorded
# Weather data for magomeni recorded
# Weather data for coquimbo recorded
# Weather data for mirnyy recorded
# Weather data for flinders recorded
# blonduos not found, skipping...
# Weather data for souillac recorded
# Weather data for barabai recorded
# Weather data for kruisfontein recorded
# Weather data for fortuna recorded
# Weather data for chapais recorded
# Weather data for hamilton recorded
# Weather data for pedernales recorded
# Weather data for chokurdakh recorded
# kapoeta not found, skipping...
# meyungs not found, skipping...
# Weather data for ossora recorded
# Weather data for samalkha recorded
# Weather data for palauig recorded
# mrirt not found, skipping...
# Weather data for coxim recorded
# Weather data for batagay-alyta recorded
# Weather data for lorengau recorded
# Weather data for la rioja recorded
# Weather data for batemans bay recorded
# Weather data for bremerton recorded
# Weather data for pisco recorded
# Weather data for odienne recorded
# Weather data for coihaique recorded
# Weather data for mozarlandia recorded
# Weather data for vostok recorded
# Weather data for andra recorded
# Weather data for natal recorded
# Weather data for amahai recorded
# Weather data for longyearbyen recorded
# tharrawaddy not found, skipping...
# jamnah not found, skipping...
# tsihombe not found, skipping...
# Weather data for salinopolis recorded
# Weather data for georgetown recorded
# Weather data for sitka recorded
# Weather data for suntar recorded
# barentsburg not found, skipping...
# Weather data for berlin recorded
# Weather data for techiman recorded
# Weather data for griffith recorded
# Weather data for bagnols-sur-ceze recorded
# Weather data for goderich recorded
# Weather data for frontera recorded
# Weather data for clyde river recorded
# Weather data for burgeo recorded
# Weather data for cidreira recorded
# Weather data for wadi musa recorded
# Weather data for byron bay recorded
# Weather data for acapulco recorded
# tsentralnyy not found, skipping...
# Weather data for lata recorded
# Weather data for maniwaki recorded
# Weather data for sayyan recorded
# Weather data for enkoping recorded
# Weather data for kuytun recorded
# utiroa not found, skipping...
# Weather data for victoria point recorded
# Weather data for akniste recorded
# Weather data for alyangula recorded
# Weather data for chernyakhovsk recorded
# Weather data for luwuk recorded
# Weather data for road town recorded
# Weather data for qaqortoq recorded
# Weather data for pochutla recorded
# Weather data for bethel recorded
# Weather data for madera recorded
# Weather data for rawson recorded
# nizhneyansk not found, skipping...
# Weather data for henties bay recorded
# Weather data for abtenau recorded
# Weather data for rupert recorded
# Weather data for tocopilla recorded
# Weather data for grabouw recorded
# Weather data for gweta recorded
# Weather data for barra do garcas recorded
# Weather data for iracoubo recorded
# Weather data for shelburne recorded
# Weather data for timra recorded
# Weather data for mount isa recorded
# Weather data for narsaq recorded
# Weather data for cherskiy recorded
# Weather data for dakar recorded
# Weather data for quatre cocos recorded
# ngukurr not found, skipping...
# Weather data for kahului recorded
# Weather data for manado recorded
# Weather data for sibolga recorded
# Weather data for reconquista recorded
# Weather data for ponta delgada recorded
# Weather data for nevinnomyssk recorded
# Weather data for havelock recorded
# Weather data for yaan recorded
# Weather data for saint anthony recorded
# Weather data for emerald recorded
# Weather data for jiayuguan recorded
# Weather data for avallon recorded
# Weather data for bundaberg recorded
# Weather data for kalanguy recorded
# ardistan not found, skipping...
# Weather data for margate recorded
# Weather data for sehithwa recorded
# Weather data for mogadishu recorded
# Weather data for owase recorded
# Weather data for sisimiut recorded
# Weather data for lindi recorded
# Weather data for saldanha recorded
# Weather data for kaputa recorded
# Weather data for sattahip recorded
# Weather data for le port recorded
# Weather data for nizhniy tsasuchey recorded
# Weather data for katsuura recorded
# Weather data for maposeni recorded
# Weather data for north myrtle beach recorded
# Weather data for ormond beach recorded
# Weather data for vila velha recorded
# Weather data for ruteng recorded
# staryy biser not found, skipping...
# urumqi not found, skipping...
# Weather data for rocha recorded
# Weather data for marica recorded
# Weather data for bonavista recorded
# Weather data for maldonado recorded
# saleaula not found, skipping...
# Weather data for denpasar recorded
# Weather data for oriximina recorded
# Weather data for leshan recorded
# Weather data for yumen recorded
# Weather data for nyurba recorded
# korla not found, skipping...
# Weather data for sarapul recorded
# Weather data for dicabisagan recorded
# Weather data for pevek recorded
# Weather data for bom jesus da lapa recorded
# Weather data for bilma recorded
# Weather data for aklavik recorded
# Weather data for santa rosa recorded
# Weather data for san mateo del mar recorded
# Weather data for half moon bay recorded
# malwan not found, skipping...
# Weather data for bronnoysund recorded
# Weather data for saint-georges recorded
# Weather data for portland recorded
# Weather data for bubaque recorded
# Weather data for fortuna foothills recorded
# Weather data for aquiraz recorded
# Weather data for california city recorded
# urdzhar not found, skipping...
# Weather data for nuevo progreso recorded
# Weather data for sao luis recorded
# Weather data for simplicio mendes recorded
# Weather data for pancas recorded
# Weather data for belaya gora recorded
# karamay not found, skipping...
# Weather data for pontianak recorded
# Weather data for elko recorded
# Weather data for pederneiras recorded
# Weather data for nazret recorded
# Weather data for nelson bay recorded
# Weather data for oktyabrskiy recorded
# Weather data for goya recorded
# Weather data for lamu recorded
# Weather data for oktyabrskoye recorded
# Weather data for padang recorded
# Weather data for klaksvik recorded
# Weather data for uchiza recorded
# Weather data for ostersund recorded
# Weather data for sinnamary recorded
# kousseri not found, skipping...
# Weather data for sioux lookout recorded
# Weather data for erenhot recorded
# Weather data for olinda recorded
# Weather data for la ronge recorded
# Weather data for mandalgovi recorded
# kamenskoye not found, skipping...
# Weather data for frederico westphalen recorded
# Weather data for lagoa recorded
# Weather data for mahon recorded
# Weather data for yefremov recorded
# Weather data for taoudenni recorded
# Weather data for praia da vitoria recorded
# Weather data for grindavik recorded
# Weather data for tema recorded
# Weather data for kautokeino recorded
# mocambique not found, skipping...
# Weather data for provost recorded
# Weather data for kudahuvadhoo recorded
# Weather data for arlit recorded
# Weather data for xinqing recorded
# Weather data for ginda recorded
# Weather data for behbahan recorded
# Weather data for vestmanna recorded
# Weather data for upata recorded
# karkaralinsk not found, skipping...
# Weather data for mandalgarh recorded
# Weather data for santa vitoria do palmar recorded
# Weather data for huarmey recorded
# kegayli not found, skipping...
# ust-kamchatsk not found, skipping...
# Weather data for babahoyo recorded
# Weather data for beinamar recorded
# Weather data for saint george recorded
# Weather data for barcelos recorded
# Weather data for mangrol recorded
# Weather data for terra santa recorded
# Weather data for honiara recorded
# Weather data for gizo recorded
# Weather data for guaranesia recorded
# ituni not found, skipping...
# Weather data for palmares do sul recorded
# Weather data for flagstaff recorded
# buqayq not found, skipping...
# Weather data for kutum recorded
# Weather data for banjar recorded
# bolungarvik not found, skipping...
# Weather data for merauke recorded
# Weather data for bathsheba recorded
# Weather data for pak phanang recorded
# bairiki not found, skipping...
# Weather data for batagay recorded
# Weather data for dolores recorded
# Weather data for ust-kulom recorded
# Weather data for trat recorded
# Weather data for virginia beach recorded
# Weather data for karema recorded
# Weather data for husavik recorded
# Weather data for ambulu recorded
# Weather data for cabedelo recorded
# Weather data for ejutla de crespo recorded
# Weather data for grand gaube recorded
# Weather data for marsa matruh recorded
# Weather data for zhezkazgan recorded
# Weather data for kavaratti recorded
# Weather data for bowen recorded
# Weather data for isla vista recorded
# Weather data for timmins recorded
# Weather data for puri recorded
# Weather data for nouadhibou recorded
# Weather data for red wing recorded
# Weather data for faya recorded
# Weather data for innisfail recorded
# Weather data for sorong recorded
# Weather data for suzun recorded
# Weather data for diego de almagro recorded
# Weather data for coolum beach recorded
# Weather data for vao recorded
# Weather data for werda recorded
# Weather data for ancud recorded
# Weather data for haines junction recorded
# jomalig not found, skipping...
# Weather data for airai recorded
# Weather data for lunenburg recorded
# Weather data for araouane recorded
# Weather data for puerto leguizamo recorded
# Weather data for westport recorded
# Weather data for oyama recorded
# lolua not found, skipping...
# rolim de moura not found, skipping...
# Weather data for tarapur recorded
# Weather data for champerico recorded
# Weather data for sal rei recorded
# Weather data for lincoln recorded
# Weather data for deputatskiy recorded
# Weather data for mezen recorded
# Weather data for san jeronimo recorded
# Weather data for cairns recorded
# Weather data for lompoc recorded
# envira not found, skipping...
# Weather data for bolobo recorded
# Weather data for lac du bonnet recorded
# Weather data for palencia recorded
# Weather data for oksfjord recorded
# Weather data for nemuro recorded
# Weather data for chauk recorded
# Weather data for camocim recorded
# Weather data for panaba recorded
# Weather data for billings recorded
# Weather data for conde recorded
# Weather data for shenjiamen recorded
# Weather data for huilong recorded
# Weather data for bertoua recorded
# Weather data for lubao recorded
# Weather data for tecoanapa recorded
# Weather data for lofthus recorded
# Weather data for colac recorded
# Weather data for caravelas recorded
# Weather data for dvinskoy recorded
# Weather data for ocampo recorded
# Weather data for san luis recorded
# Weather data for mount pleasant recorded
# Weather data for rio grande recorded
# Weather data for algiers recorded
# Weather data for anshun recorded
# Weather data for ghanzi recorded
# Weather data for minot recorded
# Weather data for aksu recorded
# Weather data for solnechnyy recorded
# Weather data for jagodina recorded
# Weather data for jalu recorded
# Weather data for riyadh recorded
# Weather data for tual recorded
# Weather data for jumla recorded
# vaitupu not found, skipping...
# Weather data for tromso recorded
# Weather data for kidal recorded
# tumannyy not found, skipping...
# Weather data for myanaung recorded
# Weather data for mabaruma recorded
# Weather data for zhigansk recorded
# Weather data for salalah recorded
# Weather data for singaraja recorded
# Weather data for carutapera recorded
# Weather data for namibe recorded
# Weather data for palu recorded
# Weather data for maceio recorded
# Weather data for plettenberg bay recorded
# marcona not found, skipping...
# Weather data for shakawe recorded
# Weather data for high level recorded
# Weather data for easton recorded
# Weather data for nizhniy kuranakh recorded
# Weather data for kieta recorded
# Weather data for shaunavon recorded
# Weather data for dhidhdhoo recorded
# Weather data for san carlos de bariloche recorded
# Weather data for lyngseidet recorded
# Weather data for gibara recorded
# Weather data for lakes entrance recorded
# Weather data for wewak recorded
# tubruq not found, skipping...
# Weather data for kakching recorded
# Weather data for freeport recorded
# Weather data for chapleau recorded
# Weather data for templin recorded
# Weather data for egvekinot recorded
# Weather data for najran recorded
# Weather data for kimbe recorded
# tahta not found, skipping...
# Weather data for khandyga recorded
# Weather data for sasovo recorded
# kazalinsk not found, skipping...
# Weather data for poindimie recorded
# klokkarvik not found, skipping...
# Weather data for tarabuco recorded
# Weather data for ambunti recorded
# Weather data for ajdabiya recorded
# Weather data for joshimath recorded
# Weather data for minab recorded
# Weather data for havre recorded
# Weather data for nicolet recorded
# Weather data for kapit recorded
# Weather data for inirida recorded
# Weather data for brookings recorded
# Weather data for puerto del rosario recorded

# %%
len(output)
# Out:
# 536

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df_list = []

for i in range(len(output)):
    df_list.append \
    ([
        output[i]['name'],   # City name
        output[i]['sys']['country'],   # Country
        output[i]['dt'],   # Date
        output[i]['coord']['lat'],   # Latitude
        output[i]['coord']['lon'],   # Longitude
        output[i]['main']['temp_max'],   # Max temperature
        output[i]['main']['humidity'],   # Humidity
        output[i]['clouds']['all'],   # Cloudiness
        output[i]['wind']['speed']   # Wind speed
    ])

result_df = pd.DataFrame \
(
    df_list, 
    columns= \
    [
        'Name',
        'Country',
        'Date',
        'Latitude',
        'Longitude',
        'Max Temperature',
        'Humidity',
        'Cloudiness',
        'Wind Speed'
    ]
)

result_df.to_csv(path_or_buf='output.csv',index=False)
result_df.head()
# Out:
#              Name Country        Date  Latitude  Longitude  Max Temperature  \
# 0  Port Elizabeth      US  1570991897     39.31     -74.98            20.56
# 1           Vaini      IN  1570991897     15.34      74.49            22.06
# 2        Jolalpan      MX  1570991898     18.32     -98.85            28.89
# 3       Dire Dawa      ET  1570991898      9.59      41.86            16.56
# 4        Thompson      CA  1570991898     55.74     -97.86             1.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        67          75       4.100
# 1        90          69       1.234
# 2        45          65       0.450
# 3        76          94       2.540
# 4        93          90       4.100

# %%
output[1]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Max Temperature'])

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Humidity'])

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Cloudiness'])

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(result_df['Latitude'],result_df['Wind Speed'])
