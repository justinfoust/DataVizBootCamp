# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine

database_path = "../Resources/Census_Data.sqlite"

# %%
# Create a connection to the Census database
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
# Query All Records in the the City Table
#census_data = pd.read_sql("SELECT * FROM Census_Data", conn)

census_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 31 columns):
# CityState                                 999 non-null object
# city                                      999 non-null object
# state                                     999 non-null object
# Population                                999 non-null int64
# White Population                          999 non-null int64
# Black Population                          999 non-null int64
# Native American Population                999 non-null int64
# Asian Population                          999 non-null int64
# Hispanic Population                       999 non-null int64
# Education None                            999 non-null int64
# Education High School                     999 non-null int64
# Education GED                             999 non-null int64
# Education Associates                      999 non-null int64
# Education Bachelors                       999 non-null int64
# ...

# %%
# Create a connection to the Zip database
zip_data_path = "../Resources/zip_census.sqlite"
engine = create_engine(f"sqlite:///{zip_data_path}")
conn = engine.connect()

# %%
# Query All Records in the Zip Table
zip_data = pd.read_sql("SELECT * FROM zip_census", conn)

zip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 32 columns):
# Median Age                                232 non-null float64
# Median Male Age                           232 non-null float64
# Median Female Age                         232 non-null float64
# Population                                232 non-null int64
# White Population                          232 non-null int64
# Black Population                          232 non-null int64
# Native American Population                232 non-null int64
# Asian Population                          232 non-null int64
# Hispanic Population                       232 non-null int64
# Education None                            232 non-null int64
# Education High School                     232 non-null int64
# Education GED                             232 non-null int64
# Education Associates                      232 non-null int64
# Education Bachelors                       232 non-null int64
# ...

# %%
# Merge the columns
pd.merge(zip_data, census_data, left_on = 'CityState', right_on = 'CityState')
# Out:
#     Median Age_x  Median Male Age_x  Median Female Age_x  Population_x  \
# 0           32.7               30.9                 33.9          2564
# 1           34.3               34.5                 33.8         23485
# 2           30.2               29.6                 30.8         12027
# 3           30.3               28.0                 31.7         11224
# 4           31.5               28.7                 33.0         27342
# 5           26.0               23.5                 30.1         30541
# 6           38.7               37.3                 40.0         14453
# 7           35.4               33.9                 37.9         13269
# 8           47.8               49.1                 47.3          2498
# 9           41.7               35.8                 43.7          7377
# 10           0.0                0.0                  0.0             0
#
#     White Population_x  Black Population_x  Native American Population_x  \
# ...

# %%
# Combined Data
