# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.random.normal(0, 0.1, 400)
y = np.random.normal(0, 0.1, 400)

# %%
plt.scatter(x,y)

# %% [markdown]
# ### Pass a Dictionary to `plt.scatter()` for formatting

# %%
parameters = {}

# %%
plt.scatter(**parameters)

# %%
def sumNum(a, b):
    return a+b

# %%
sumNum(*[1,4])
# Out:
# 5
