# %% [markdown]
# # Hello Variable World

# %% [markdown]
# ### Day 1 - Activies - 04-Stu_HelloVariableWorld

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = "Justin"
country = "USA"
age = 37
hourlyWage = 1000
satisfied = True
dailyWage = 8 * hourlyWage

# %%
print("My name is " + name + ", I live in " + country + ", I am " + str(age) + " years old, I make " + str(hourlyWage) + " dollars per hour.")
# Out:
# My name is Justin, I live in USA, I am 37 years old, I make 1000 dollars per hour.

# %%
print(f"I make {dailyWage} per day and my satisfaction is {satisfied}")
# Out:
# I make 8000 per day and my satisfaction is True
