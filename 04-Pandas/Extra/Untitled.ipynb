# %%
import pandas as pd

# %%
df = pd.read_csv("Data/college.csv")

df.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
df.groupby(['CITY']).count()
# Out:
#               INSTNM  STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  \
# CITY
# ARTESIA            1       1     1        1          1         1         0
# Aberdeen           3       3     3        3          3         3         2
# Abilene            5       5     5        5          5         5         3
# Abingdon           2       2     2        2          2         2         0
# Abington           1       1     1        1          1         1         1
# ...              ...     ...   ...      ...        ...       ...       ...
# Yucaipa            1       1     1        1          1         1         0
# Yucca Valley       1       1     1        1          1         1         0
# Yukon              1       1     1        1          1         1         0
# Yuma               1       1     1        1          1         1         0
# Zanesville         3       3     3        3          3         3         0
#
# ...

# %%
df.columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
df['WOMENONLY'].value_counts(normalize=True)
# Out:
# 0.0    0.994696
# 1.0    0.005304
# Name: WOMENONLY, dtype: float64

# %%
df.SATVRMID.describe()
# Out:
# count    1185.000000
# mean      522.819409
# std        68.578862
# min       290.000000
# 25%       475.000000
# 50%       510.000000
# 75%       555.000000
# max       765.000000
# Name: SATVRMID, dtype: float64

# %%
bins = [0,100,200,300,1000]

labels = ['0-99','100-199','200-299','>300']

df['SATBINS'] = pd.cut(df['SATVRMID'], bins, right=False)
df[['CITY', 'SATVRMID', 'SATBINS']].head(10)
# Out:
#              CITY  SATVRMID          SATBINS
# 0          Normal     424.0  [300.0, 1000.0)
# 1      Birmingham     570.0  [300.0, 1000.0)
# 2      Montgomery       NaN              NaN
# 3      Huntsville     595.0  [300.0, 1000.0)
# 4      Montgomery     425.0  [300.0, 1000.0)
# 5      Tuscaloosa     555.0  [300.0, 1000.0)
# 6  Alexander City       NaN              NaN
# 7          Athens       NaN              NaN
# 8      Montgomery     486.0  [300.0, 1000.0)
# 9          Auburn     575.0  [300.0, 1000.0)
