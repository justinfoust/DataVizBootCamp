# %%
# Dependencies
import os
import pandas as pd

# %%
# Load in File from resources
# 'movie_scores.csv'

csvFilePath = os.path.join('Resources','movie_scores.csv')

movieScores_df = pd.read_csv(csvFilePath)

movieScores_df.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
# Read and display with pandas
movieScores_df.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
# List all the columns the table provides
movieScores_d

# %%
a = [i for i in movieScores_df.columns if 'IMDB' in i]
b = ["FILM"] + a

for i in movieScores_df.columns:
    if "IMDB" in i:
        print(i)
# Out:
# IMDB
# IMDB_norm
# IMDB_norm_round
# IMDB_user_vote_count

# %%
# only care about Imdb, so create a new table that takes the Film and all the columns relating to IMDB
newScores_df = movieScores_df[b]
newScores_df.head()
# Out:
#                              FILM  IMDB  IMDB_norm  IMDB_norm_round  \
# 0  Avengers: Age of Ultron (2015)   7.8       3.90              4.0
# 1               Cinderella (2015)   7.1       3.55              3.5
# 2                  Ant-Man (2015)   7.8       3.90              4.0
# 3          Do You Believe? (2015)   5.4       2.70              2.5
# 4   Hot Tub Time Machine 2 (2015)   5.1       2.55              2.5
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %%
# List only movies whose ratings are over 7 (out of 10) in IMDB
goodMovies_df = newScores_df.loc[newScores_df["IMDB"] < 7, :]

goodMovies_df.head()
# Out:
#                              FILM  IMDB  IMDB_norm  IMDB_norm_round  \
# 3          Do You Believe? (2015)   5.4       2.70              2.5
# 4   Hot Tub Time Machine 2 (2015)   5.1       2.55              2.5
# 6           Irrational Man (2015)   6.9       3.45              3.5
# 7                 Top Five (2014)   6.5       3.25              3.5
# 11               Black Sea (2015)   6.4       3.20              3.0
#
#     IMDB_user_vote_count
# 3                   3136
# 4                  19560
# 6                   2680
# 7                  16876
# 11                 16547

# %%
# Find lesser-known movies to watch, with fewer than 20K votes
lesserKnownMovies_df = newScores_df.loc[
    
    (newScores_df["IMDB_user_vote_count"] < 20000) & (newScores_df['IMDB'] > 7), :
]

lesserKnownMovies_df.head(100)
# Out:
#                                                   FILM  IMDB  IMDB_norm  \
# 8                         Shaun the Sheep Movie (2015)   7.4       3.70
# 9                                  Love & Mercy (2015)   7.8       3.90
# 10                   Far From The Madding Crowd (2015)   7.2       3.60
# 20                               McFarland, USA (2015)   7.5       3.75
# 29                          The End of the Tour (2015)   7.9       3.95
# 30                                     Red Army (2015)   7.7       3.85
# 31                        When Marnie Was There (2015)   7.8       3.90
# 32                           The Hunting Ground (2015)   7.5       3.75
# 41                                     Timbuktu (2015)   7.2       3.60
# 66                                     The Gift (2015)   7.6       3.80
# 68                               Monkey Kingdom (2015)   7.3       3.65
# 70                     Seymour: An Introduction (2015)   7.7       3.85
# ...

# %%
# Finally, export this file to an Excel spreadsheet -- without the DataFrame index.
goodMovies_df.to_excel('good_movies.xls', index=False)
